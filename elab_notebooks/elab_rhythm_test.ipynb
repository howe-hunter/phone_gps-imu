# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
fname = 'space/undergrad_work/hunterh/notes/gps_tests/test_3_rhythm/20210823_040530/'

# %%
df = pd.read_csv(r'/home/hunter/hunter_sync/space/undergrad_work/hunterh/notes/gps_tests/test_3_rhythm/20210823_040530/20210823_040530.csv')
df
# Out:
#      Longitude  Latitude  Speed  Distance      Time     Acc X     Acc Y  \
# 0          0.0       0.0    0.0       0.0  04-05-31 -0.007417  0.050377
# 1          0.0       0.0    0.0       0.0  04-05-31 -0.007417  0.050377
# 2          0.0       0.0    0.0       0.0  04-05-31 -0.007417  0.050377
# 3          0.0       0.0    0.0       0.0  04-05-31 -0.003464  0.041011
# 4          0.0       0.0    0.0       0.0  04-05-31 -0.003464  0.041011
# ..         ...       ...    ...       ...       ...       ...       ...
# 268        0.0       0.0    0.0       0.0  04-05-49  0.062745 -0.101677
# 269        0.0       0.0    0.0       0.0  04-05-49  0.062745 -0.101677
# 270        0.0       0.0    0.0       0.0  04-05-49  0.062745 -0.101677
# 271        0.0       0.0    0.0       0.0  04-05-49  0.062745 -0.101677
# 272        0.0       0.0    0.0       0.0  04-05-49  0.062745 -0.101677
#
#         Acc Z  Heading    gyro_x    gyro_y    gyro_z
# ...

# %%
plt.plot(df['gyro_x'])

# %%
plt.plot(df['gyro_y'])

# %%
plt.plot(df['gyro_z'])

# %%
plt.plot(df['gyro_x'])
plt.plot(df['gyro_y'])
plt.plot(df['gyro_z'])

# %%
plt.plot(df['gyro_x'][0:15],".-")
plt.plot(df['gyro_y'][0:15])
plt.plot(df['gyro_z'][0:15])
